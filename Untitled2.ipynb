# %%
import cv2
from google.colab.patches import cv2_imshow

image_path ='/content/Winniethepooh.png'

# Read the image using cv2.imread()
img=cv2.imread(image_path)
#check if the image was loaded successfully
if img is None:
  print(f"Error:i]Image not found at {image_path} or unable to load.")
else:
    #Display the image using cv2_imshow
    cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=266x373>
